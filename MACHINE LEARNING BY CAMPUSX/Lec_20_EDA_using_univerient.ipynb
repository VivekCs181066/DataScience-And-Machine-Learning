# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical columns

# %% [markdown]
# Countplot

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10,6))

# Create countplot with custom colors and style
sns.countplot(data=df, x='Survived', palette='Set2')

# Customize the plot
plt.title('Distribution of Survival', fontsize=14, pad=15)
plt.xlabel('Survived (0=No, 1=Yes)', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Add value labels on top of bars
for i in plt.containers:
    plt.bar_label(i, fontsize=11)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_11556\669047363.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Survived', palette='Set2')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 15
#      12 plt.ylabel('Count', fontsize=12)
#      14 # Add value labels on top of bars
# ---> 15 for i in plt.containers:
#      16     plt.bar_label(i, fontsize=11)
#      18 # Adjust layout
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'containers'

# %%
df['Survived'].value_counts().plot(kind='bar', color=['red','green'])
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='bar',color=['red','green','blue'])
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='bar',color=['red','green'])
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%1.2f%%', startangle=90, shadow=True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data Visualization

# %% [markdown]
# 1. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], bins=30, color='blue', edgecolor='black')
# Out:
# (array([30., 14., 10., 14.,  3., 29., 39., 65., 73., 42., 65., 62., 33.,
#         47., 38., 21., 28., 21., 16., 14., 15.,  7.,  9.,  8.,  4.,  0.,
#          5.,  1.,  0.,  1.]),
#  array([ 0.42      ,  3.07266667,  5.72533333,  8.378     , 11.03066667,
#         13.68333333, 16.336     , 18.98866667, 21.64133333, 24.294     ,
#         26.94666667, 29.59933333, 32.252     , 34.90466667, 37.55733333,
#         40.21      , 42.86266667, 45.51533333, 48.168     , 50.82066667,
#         53.47333333, 56.126     , 58.77866667, 61.43133333, 64.084     ,
#         66.73666667, 69.38933333, 72.042     , 74.69466667, 77.34733333,
#         80.        ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# 2. Distplot

# %%
sns.distplot(df['Age'].dropna(), bins=30, color='blue', hist_kws={'edgecolor':'black'}) # PDF (Probarbility Density Function)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_11556\3305948074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(), bins=30, color='blue', hist_kws={'edgecolor':'black'}) # PDF (Probarbility Density Function)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# 3. Boxplot

# %%
sns.boxplot(y=df['Fare'], color='lightblue')
# Out:
# <Axes: ylabel='Fare'>
